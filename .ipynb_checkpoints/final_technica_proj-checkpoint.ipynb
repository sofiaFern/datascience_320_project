# %% [markdown]
# # Understanding the Demographics & Influence of Technica
#
# ### By Raghav Chetal and Sofia Fernandez-Poyatos
#
# <p> Computer Science has always been a generally male-dominated career, with only 18% of all computer scientists being women and 20% of Computer Science students being women at University of Maryland. </p>
#
# ![](technica_cover.jpg)

# %% [markdown]
# ## Our Motivation
#
# [Technica](https://gotechnica.org) is the world's largest all-women and nonbinary hackathon, hosted annually at the University of Maryland. Since its inception in 2015, Technica has been putting a spotlight on women in the computer science workplace and empowering them to succeed.
# <br><br>
# We've both been involved with Technica's organization through director and mentor positions. We are interested in understanding Technica's influence in different age groups, studies and states.
# <br><br>
# We received permission from the Technica organizing team to use several participant registration datasets. In this tutorial, we will focus on 2018's registration data, because it is the most completed.
#
# This dataset includes information such as:
# <br>
# * Age
# * Major
# * School
# * Background/Ethnicity
# * Gender
# * State
# * Institution/University
# * Retention Rate
#
# ## Required Libraries¶
# Here are the libraries we used for our tutorial and how we used them:
# <br>
# * _pandas_ : a data analysis toolkit which makes storing and accessing data easier
# * _numpy_ : a package for mathematical computing
# * _seaborns_ : creating graphs (pie charts, bar charts, etc.)
# * _re_ : using regex to select preferred word
# * _beautifulsoup4_ : to scrape web for coordinates of states to plot on map
# * _requests_ : to access url page to scrape for bs4
# * _folium_ : creating map visualizations of hackers
# * _sklearn_ : making regressions and doing statistical analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import folium
import sklearn
import matplotlib
import re
from bs4 import BeautifulSoup
import requests

matplotlib.style.use("ggplot")

data2019 = pd.read_csv("technica_data_2019.csv")
data2018 = pd.read_csv("technica_data_2018.csv")
print(data2019.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2241 entries, 0 to 2240
# Data columns (total 33 columns):
# When is your birthdate?                                                                                            2241 non-null object
# What is your gender identity?                                                                                      2193 non-null object
# Other                                                                                                              48 non-null object
# What are your preferred pronouns?                                                                                  2187 non-null object
# Other.1                                                                                                            54 non-null object
# American Indian or Alaska Native                                                                                   18 non-null object
# Asian / Pacific Islander                                                                                           1217 non-null object
# Black or African American                                                                                          357 non-null object
# Hispanic or Latino                                                                                                 180 non-null object
# Middle Eastern or North African                                                                                    88 non-null object
# Native Hawaiian or Other Pacific Islander                                                                          13 non-null object
# White/Caucasian                                                                                                    441 non-null object
# Prefer not to answer                                                                                               88 non-null object
# Other.2                                                                                                            32 non-null object
# State                                                                                                              2241 non-null object
# If you're not coming from the United States, please name the country you are coming from.                          80 non-null object
# What level of school are you in?                                                                                   2169 non-null object
# What is the name of your school?                                                                                   474 non-null object
# What institution do you attend?                                                                                    1760 non-null object
# Please type in your university.                                                                                    226 non-null object
# What is your major?                                                                                                1760 non-null object
# Please type in your major.                                                                                         193 non-null object
# What is your expected year of graduation?                                                                          1679 non-null float64
# Is this your first time at Technica?                                                                               2241 non-null int64
# Was Technica the first hackathon you attended?                                                                     490 non-null float64
# Have you also attended Bitcamp before?                                                                             480 non-null float64
# Were there any significant differences between your experiences at these two hackathons? If so, please explain.    98 non-null object
# Have you attended Bitcamp before?                                                                                  1742 non-null float64
# How, if at all, did your experience at Bitcamp affect your decision to attend Technica?                            64 non-null object
# Are you interested in attending another hackathon in the near future?                                              2225 non-null float64
# Do you need transportation to Technica?                                                                            2226 non-null float64
# Interested in taking one of our free buses?                                                                        908 non-null float64
# Tell us what school you're coming from!                                                                            810 non-null object
# dtypes: float64(7), int64(1), object(25)
# memory usage: 577.9+ KB
# None

# %% [markdown]
# ## Data Curation
# Before uploading the CSV files we removed any private data (i.e. participants name, email and t-shirt size). Here we will remove any unecessary data (food restrictions, pronouns, tokens, and unnamed columns) that do not contribute to our analysis

# %%
# data2018.drop(['Food Restrictions'])
clean_data = data2018.drop(['Preferred Pronouns', 'Food Restrictions','Unnamed: 14','Unnamed: 18',
                        'Unnamed: 19','Unnamed: 20', 'University'], axis = 'columns')
clean_data
# Out:
#       Age  Birthday Gender Identity               Backgrounds  \
# 0      22   5/18/96          Female        Hispanic or Latino
# 1      17   5/15/01          Female  Asian / Pacific Islander
# 2      21  10/25/97          Female      Prefer not to answer
# 3      20   9/22/98          Female  Asian / Pacific Islander
# 4      20   3/12/98          Female  Asian / Pacific Islander
# ...   ...       ...             ...                       ...
# 2219   16   1/17/02          Female  Asian / Pacific Islander
# 2220   16    1/1/02          Female           White/Caucasian
# 2221   20  11/10/98             NaN                       NaN
# 2222   23  12/29/94          Female                       NaN
# 2223   13   4/22/05      Non-binary        Hispanic or Latino
#
#                  School Level Graduation Year First Hackathon?  \
# 0     College (Undergraduate)            2019             True
# 1                 High School            2019             True
# 2     College (Undergraduate)            2020            False
# 3     College (Undergraduate)            2021             True
# 4     College (Undergraduate)            2020            False
# ...                       ...             ...              ...
# 2219              High School            2020            False
# 2220              High School            2020             True
# 2221                      NaN             NaN              NaN
# 2222                      NaN             NaN              NaN
# 2223            Middle School            2025             True
#
#      First Technica?       Location                          Institution  \
# 0               True          Olney  University of Maryland College Park
# 1               True  Ellicott City                                  NaN
# 2               True   Gaithersburg  University of Maryland College Park
# 3               True   College Park  University of Maryland College Park
# 4               True   College Park  University of Maryland College Park
# ...              ...            ...                                  ...
# 2219           False  Rockville, MD                                  NaN
# 2220            True   Columbia, MD                                  NaN
# 2221             NaN            NaN                                  NaN
# 2222             NaN            NaN                                  NaN
# 2223            True          Texas                                  NaN
#
#                                      Major     State Country (non-USA)  \
# 0     Environmental Science and Technology  Maryland               NaN
# 1                                      NaN  Maryland               NaN
# 2                         Computer Science  Maryland               NaN
# 3                   Mechanical Engineering  Maryland               NaN
# 4                           Bioengineering  Maryland               NaN
# ...                                    ...       ...               ...
# 2219                                   NaN       NaN               NaN
# 2220                                   NaN       NaN               NaN
# 2221                                   NaN       NaN               NaN
# 2222                                   NaN       NaN               NaN
# 2223                                   NaN       NaN               NaN
#
#      Tech + Research Track?
# 0                      True
# 1                     False
# 2                     False
# 3                      True
# 4                      True
# ...                     ...
# 2219                    NaN
# 2220                    NaN
# 2221                    NaN
# 2222                    NaN
# 2223                    NaN
#
# [2224 rows x 14 columns]

# %% [markdown]
# ## General Understand of User Data
# We are going to create several graphs in order to have an understanding of what kinds of participants attend Technica.
# <br> <br>
# First we will take a look at what kind of age range of people are registered and interest in Technica using a bargraph and take a look at what kinds of majors as well as what kinds of majors are registering through a bar graph.

# %%
#majors
minors = 0
college = 0
post_college = 0

ages = data2018['Age']
for age in ages:
    if int(age) <18:
        minors += 1
    elif int(age) >= 18 and int(age) <= 23:
        college += 1
    else:
        post_college += 1


x = ['Minors', 'College', 'Post College']
y = [minors, college, post_college]

my_plot = sns.barplot(x, y);
my_plot.set(xlabel ='Type of Registrant', ylabel = 'Number of People') 
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec


df_major = pd.DataFrame(data2018['Major'].value_counts())
df_major = df_major.head(15)
major_clean = df_major.reset_index()
major_clean.columns = ['Major', 'Num'] 

sns.set(style="whitegrid")
plt.figure(2, figsize=(20,15))
the_grid = GridSpec(2, 2)

plt.subplot(the_grid[0, 1],  title='# of People per Major')
sns.barplot(x='Num',y='Major', data=major_clean, palette='Spectral')

# %%
# Removes invalid answers, surveys were self-fill, so there is some invalid data
occurrences = data['Gender Identity'].value_counts()[0:2]

# Creates a Pie Chart of the Gender Identity data
plt.figure(figsize = (24, 18))
occurrences.plot.pie(y=occurrences.index,
           shadow=False,
           colors=colors, 
           explode=(0, 0.1),
           startangle=90,
           autopct='%1.1f%%',
        textprops={'fontsize': 24})

plt.axis('equal')
plt.title('Gender Distribution', fontsize = 30)
plt.show()

# %%
# Removes invalid answers, surveys were self-fill (Remove ages under 5)
age_fix = data[data['Age'] > 5]

# Plot the Barplot
plt.figure(figsize = (24, 18))
occurrences = age_fix['Age'].value_counts()
ax = sns.barplot(x=occurrences.keys(), y=occurrences.values, data=data)
plt.title('Age vs. Number of Attendants', fontsize = 30)
plt.ylabel('Number of Attendants', fontsize = 26)
plt.xlabel('Age', fontsize = 26)
plt.show()

# %% [markdown]
# ## Map of Hackers in the USA

# %%
save_states = clean_data['State'].dropna().value_counts()
save_states
# Out:
# Maryland          963
# New York          190
# Virginia          189
# Pennsylvania      100
# New Jersey         77
# Other              71
# North Carolina     38
# Massachusetts      31
# California         28
# Indiana            25
# Florida            23
# Texas              16
# Washington         13
# Georgia            12
# Illinois           11
# Ohio                7
# Michigan            7
# West Virginia       6
# Delaware            5
# Tennessee           5
# Wisconsin           5
# Rhode Island        5
# Utah                4
# Louisiana           3
# Kentucky            3
# South Carolina      3
# Alabama             3
# Iowa                2
# Connecticut         2
# Minnesota           1
# Arizona             1
# Alaska              1
# Name: State, dtype: int64

# %%
page_info = requests.get("https://www.latlong.net/category/states-236-14.html")
soup_info = BeautifulSoup(page_info.text)

map_coordinates = soup_info.find(class_='col-8')
coordinates = map_coordinates.find_all('td')

our_state_list = ['Maryland','New York','Virginia', 'Pennsylvania','New Jersey','North Carolina','Massachusetts'
             'California', 'Indiana', 'Florida', 'Texas', 'Washington', 'Georgia', 'Illinois', 'Ohio',
             'Michigan','West Virginia', 'Delaware', 'Tennessee', 'Wisconsin', 'Rhode Island', 'Utah', 
             'Louisiana', 'Kentucky', 'South Carolina', 'Alabama', 'Iowa', 'Connecticut', 'Minnesota',
             'Arizona', 'Alaska']
fresh_state_list = []
lat_list = []
lon_list = []

count = 1
# for coord in coordinates:
for i in range(0,len(coordinates)-1,3):
    #parsing for state name
    info = str(coordinates[i].contents)
        
    find_state = re.findall(r'title="\w+,|title="\w+\s\w+,', info)

    find_state = find_state[0].replace("title=\"", "")
    find_state = find_state[:-1]
    
    if find_state in our_state_list:
        fresh_state_list.append(find_state)
        lon_list.append(coordinates[i+1].contents[0])
        lat_list.append(coordinates[i+2].contents[0])

map_data = pd.DataFrame({
    'name':fresh_state_list,
    'lat':lat_list,
    'lon':lon_list,
})

map_data
# Out:
#               name          lat        lon
# 0        Wisconsin   -89.500000  44.500000
# 1    West Virginia   -80.500000  39.000000
# 2            Texas  -100.000000  31.000000
# 3     Rhode Island   -71.500000  41.700001
# 4         New York   -75.000000  43.000000
# 5         Illinois   -89.000000  40.000000
# 6         Delaware   -75.500000  39.000000
# 7      Connecticut   -72.699997  41.599998
# 8          Indiana   -86.126976  40.273502
# 9          Florida   -81.760254  27.994402
# 10        Michigan   -84.506836  44.182205
# 11         Georgia   -83.441162  33.247875
# 12          Alaska  -153.369141  66.160507
# 13       Tennessee   -86.660156  35.860119
# 14        Virginia   -78.024902  37.926868
# 15      New Jersey   -74.871826  39.833851
# 16        Kentucky   -84.270020  37.839333
# 17       Minnesota   -94.636230  46.392410
# 18      Washington  -120.740135  47.751076
# 19            Utah  -111.950684  39.419220
# 20            Ohio   -82.996216  40.367474
# 21         Alabama   -86.902298  32.318230
# 22            Iowa   -93.581543  42.032974
# 23  South Carolina   -81.163727  33.836082
# 24    Pennsylvania   -77.194527  41.203323
# 25         Arizona  -111.093735  34.048927
# 26        Maryland   -76.641273  39.045753
# 27  North Carolina   -80.793457  35.782169
# 28       Louisiana   -92.329102  30.391830

# %%
map = folium.Map(location=[30, -90], zoom_start=4)

for i in range(0,len(map_data)):
    folium.Marker([map_data.iloc[i]['lon'], map_data.iloc[i]['lat']], popup=map_data.iloc[i]['name']).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#major bar graphs
majors = clean_data['Major'].dropna().value_counts()
majors.head(100)

major_df = pd.DataFrame(majors)
major_df = major_df.reset_index()
major_df.columns = ['Major', 'Num'] # change column names
major_clean = major_df.head(14)

# %%
#majors
